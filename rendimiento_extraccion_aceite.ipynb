# %% [markdown]
# <a href="https://colab.research.google.com/github/Pannda23/notebook_agro_2026_1/blob/main/rendimiento_extraccion_aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **JESUS ELIAS MARTINEZ SALCEDO**

# %% [markdown]
# #**Control de Rendimiento en Extracción de Aceite**
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **planteamiento**
#
# Una planta procesadora de palma de aceite necesita calcular el Índice de Rendimiento de Extracción (IRE). El operario debe ingresar el peso total de los racimos de fruta fresca (RFF) procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos**:
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg  (Tipo float).(Pr).
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (Lt).
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L (R)
# .
# $$Pa (kg)=Lt×0.92$$
# $$R=(Pa/Pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan **1000 kg** de racimos y se obtienen **200 litros** de aceite, el programa debe informar que el rendimiento del lote es del **18.4%.**

# %%
#entrada Solicitar el nombre del lote de producción (Tipo string).
#Solicitar el peso de los racimos en kg  (Tipo float).(Pr).
#Solicitar los litros de aceite obtenidos  (Tipo float).(Lt).
nombre = input("Ingrese el nombre del lote: ")
Pr = float(input("Ingrese el peso de los racimos en kg: "))
Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

#proceso calcular el peso del aceite (Pa) y el rendimiento (R)
Pa = Lt * 0.92
R = (Pa / Pr) * 100

#salida infromar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", R, "%.")
# Out:
# Ingrese el nombre del lote: perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote perico es del 18.4 %.

# %% [markdown]
# Aquí te presento una explicación detallada de cada línea del código:
#
# ```python
# #entrada Solicitar el nombre del lote de producción (Tipo string).
# #Solicitar el peso de los racimos en kg  (Tipo float).(Pr).
# #Solicitar los litros de aceite obtenidos  (Tipo float).(Lt).
# nombre = input("Ingrese el nombre del lote: ")
# Pr = float(input("Ingrese el peso de los racimos en kg: "))
# Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
#
# #proceso calcular el peso del aceite (Pa) y el rendimiento (R)
# Pa = Lt * 0.92
# R = (Pa / Pr) * 100
#
# #salida infromar el rendimiento del lote
# print("El rendimiento del lote", nombre, "es del", R, "%.")
# ```
#
# **Explicación Línea por Línea:**
#
# 1.  `#entrada Solicitar el nombre del lote de producción (Tipo string).`
#     *   Este es un **comentario** que documenta la sección de "entrada" de datos y el primer requerimiento: solicitar el nombre del lote de producción, el cual debe ser de tipo `string` (cadena de texto).
#
# 2.  `#Solicitar el peso de los racimos en kg (Tipo float).(Pr).`
#     *   Este es otro **comentario** que describe el segundo requerimiento: solicitar el peso de los racimos en kilogramos, que será un número decimal (`float`), y se almacenará en la variable `Pr`.
#
# 3.  `#Solicitar los litros de aceite obtenidos (Tipo float).(Lt).`
#     *   Este **comentario** indica el tercer requerimiento: solicitar la cantidad de litros de aceite obtenidos, que también será un número decimal (`float`), y se guardará en la variable `Lt`.
#
# 4.  `nombre = input("Ingrese el nombre del lote: ")`
#     *   Esta línea usa la función `input()` para mostrar el mensaje "Ingrese el nombre del lote: " al usuario. La respuesta del usuario (una cadena de texto) se asigna a la variable `nombre`.
#
# 5.  `Pr = float(input("Ingrese el peso de los racimos en kg: "))`
#     *   Aquí, `input()` solicita al usuario el peso de los racimos. La función `float()` convierte la cadena de texto ingresada por el usuario a un número de punto flotante (decimal), que luego se guarda en la variable `Pr`.
#
# 6.  `Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))`
#     *   De forma similar a la anterior, `input()` pide los litros de aceite. `float()` convierte la entrada a un número decimal, y el resultado se almacena en la variable `Lt`.
#
# 7.  `#proceso calcular el peso del aceite (Pa) y el rendimiento (R)`
#     *   Este **comentario** marca la sección del "proceso" donde se realizan los cálculos, específicamente el peso del aceite (`Pa`) y el rendimiento (`R`).
#
# 8.  `Pa = Lt * 0.92`
#     *   Esta línea calcula el peso del aceite en kilogramos (`Pa`). Multiplica los litros de aceite (`Lt`) por la densidad aproximada del aceite (0.92 kg/L). El resultado se guarda en `Pa`.
#
# 9.  `R = (Pa / Pr) * 100`
#     *   Esta línea calcula el Índice de Rendimiento de Extracción (`R`). Divide el peso del aceite (`Pa`) por el peso total de los racimos (`Pr`) y multiplica el resultado por 100 para obtener un porcentaje. El valor final se almacena en `R`.
#
# 10. `#salida infromar el rendimiento del lote`
#     *   Este **comentario** indica la sección de "salida", donde los resultados serán presentados al usuario.
#
# 11. `print("El rendimiento del lote", nombre, "es del", R, "%.")`
#     *   Esta línea usa la función `print()` para mostrar un mensaje informativo al usuario. Combina el texto fijo con los valores de las variables `nombre` y `R` para indicar el rendimiento del lote, por ejemplo: "El rendimiento del lote perico es del 18.4 %."
